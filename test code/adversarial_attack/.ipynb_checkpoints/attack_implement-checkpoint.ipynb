# %% [markdown]
# # Test Case: Attack FP-ResNet-20

# %% [markdown]
# 下面是针对本模块6种方法的功能测试及结果，亦可作为测试组再次测试的测试代码。
#
# 该部分在测试前需安装PytorchPlus安装包以及[软件设计文档](https://github.com/bhsei/20_A/blob/master/%E5%AE%9E%E9%AA%8C3%EF%BC%9A%E8%BD%AF%E4%BB%B6%E4%BA%A7%E5%93%81%E6%94%B9%E8%BF%9B%E4%B8%8E%E5%B1%95%E7%A4%BA/TeamA-%E8%BD%AF%E4%BB%B6%E8%AE%BE%E8%AE%A1%E6%96%87%E6%A1%A3_v3.0.docx)中规定的环境依赖。同时，在测试时需要分别完成对下列shell文件中argument的替换：
# * **modelpath** "FP_ResNet20.th"文件在测试环境的路径（建议使用绝对路径）；
# * **dataroot** 数据集的位置，因为本测试用例针对的是CIFAR-10数据集，提供该数据集文件夹的路径；
# * **savepath** 存储生成的对抗样本集合的路径。

# %%
# !python test_attack.py \
  --attack "fgsm" \
  --generate "False" \
  --model "FP_ResNet20" \
  --modelpath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/FP_ResNet20.th" \
  --dataroot '/home/jovyan/yuhang/Wasserstein/datasets/CIFAR10/' \
  --attack_batchsize 200 \
  --attack_epsilon 1.0 \
  --attack_iter 10 \
  --savepath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/Samples/" \
  --dataset "CIFAR-10" \
  --arch "resnet20"
# !echo "---------------------------------------------------------------------"
# !python test_attack.py \
  --attack "stepll" \
  --generate "False" \
  --model "FP_ResNet20" \
  --modelpath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/FP_ResNet20.th" \
  --dataroot '/home/jovyan/yuhang/Wasserstein/datasets/CIFAR10/' \
  --attack_batchsize 200 \
  --attack_epsilon 1.0 \
  --attack_iter 10 \
  --savepath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/Samples/" \
  --dataset "CIFAR-10" \
  --arch "resnet20"
# !echo "---------------------------------------------------------------------"
# !python test_attack.py \
  --attack "pgd" \
  --generate "False" \
  --model "FP_ResNet20" \
  --modelpath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/FP_ResNet20.th" \
  --dataroot '/home/jovyan/yuhang/Wasserstein/datasets/CIFAR10/' \
  --attack_batchsize 200 \
  --attack_epsilon 1.0 \
  --attack_iter 10 \
  --savepath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/Samples/" \
  --dataset "CIFAR-10" \
  --arch "resnet20"
# !echo "---------------------------------------------------------------------"
# !python test_attack.py \
  --attack "momentum_ifgsm" \
  --generate "False" \
  --model "FP_ResNet20" \
  --modelpath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/FP_ResNet20.th" \
  --dataroot '/home/jovyan/yuhang/Wasserstein/datasets/CIFAR10/' \
  --attack_batchsize 200 \
  --attack_epsilon 1.0 \
  --attack_iter 10 \
  --savepath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/Samples/" \
  --dataset "CIFAR-10" \
  --arch "resnet20"
# !echo "---------------------------------------------------------------------"
# !python test_attack.py \
  --attack "Fourier" \
  --generate "False" \
  --model "FP_ResNet20" \
  --modelpath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/FP_ResNet20.th" \
  --dataroot '/home/jovyan/yuhang/Wasserstein/datasets/CIFAR10/' \
  --attack_batchsize 200 \
  --attack_epsilon 1.0 \
  --attack_iter 10 \
  --savepath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/Samples/" \
  --dataset "CIFAR-10" \
  --arch "resnet20"
# !echo "---------------------------------------------------------------------"
# !python test_attack.py \
  --attack "CW_L2" \
  --generate "False" \
  --model "FP_ResNet20" \
  --modelpath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/FP_ResNet20.th" \
  --dataroot '/home/jovyan/yuhang/Wasserstein/datasets/CIFAR10/' \
  --attack_batchsize 200 \
  --attack_epsilon 1.0 \
  --attack_iter 10 \
  --savepath "/home/jovyan/TheVirtuoso/BNN_ADV/Data/Samples/" \
  --dataset "CIFAR-10" \
  --arch "resnet20"
# Out:
# attack FP_ResNet20 model
# epsilon :  1.0
# Before FGSM the accuracy is 91.73
# After FGSM the accuracy is 46.79
# ---------------------------------------------------------------------
# attack FP_ResNet20 model
# epsilon :  1.0
# Before Step-ll the accuracy is 91.73
# After Step-ll the accuracy is 63.96
# ---------------------------------------------------------------------
# attack FP_ResNet20 model
# epsilon :  1.0
# PGD alpha is  0.0012401088863405409
# Before PGD the accuracy is 91.73
# After PGD the accuracy is 20.08
# ---------------------------------------------------------------------
# attack FP_ResNet20 model
# epsilon :  1.0
# MI-FGSM alpha is  0.0012401088863405409
# Before Momentum IFGSM the accuracy is 91.73
# After Momentum IFGSM the accuracy is 22.05
# ---------------------------------------------------------------------
# attack FP_ResNet20 model
# epsilon :  1.0
# ---------------------------------------------------------------------
# attack FP_ResNet20 model
# ...
